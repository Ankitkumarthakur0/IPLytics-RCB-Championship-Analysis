# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("IPLytics Started Successfully")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# IPLytics Started Successfully
